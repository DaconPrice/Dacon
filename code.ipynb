# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 50

# %%
train_df = pd.read_csv('../data/dacon_veg/train/train.csv')
train_meta_1 = pd.read_csv('../data/dacon_veg/train/meta/TRAIN_산지공판장_2018-2021.csv')
train_meta_2 = pd.read_csv('../data/dacon_veg/train/meta/TRAIN_전국도매_2018-2021.csv')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29376 entries, 0 to 29375
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시점          29376 non-null  object
#  1   품목명         29376 non-null  object
#  2   품종명         29376 non-null  object
#  3   거래단위        29376 non-null  object
#  4   등급          29376 non-null  object
#  5   평년 평균가격(원)  29376 non-null  float64
#  6   평균가격(원)     29376 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 1.6+ MB

# %%
train_df['품목명'].nunique()
# Out:
# 10

# %%
train_df[(train_df['품목명']=='감자') & (train_df['품종명']== '감자 수미') & (train_df['등급']== '상')]
# Out:
#             시점 품목명    품종명    거래단위 등급    평년 평균가격(원)       평균가격(원)
# 1872  201801상순  감자  감자 수미  20키로상자  상  24660.031746  44170.285714
# 1873  201801중순  감자  감자 수미  20키로상자  상  23299.444444  48283.777778
# 1874  201801하순  감자  감자 수미  20키로상자  상  25218.007407  50243.000000
# 1875  201802상순  감자  감자 수미  20키로상자  상  28703.875000  55380.666667
# 1876  201802중순  감자  감자 수미  20키로상자  상  27419.882275  59133.000000
# ...        ...  ..    ...     ... ..           ...           ...
# 2011  202111중순  감자  감자 수미  20키로상자  상  30634.777778  33761.333333
# 2012  202111하순  감자  감자 수미  20키로상자  상  32139.787037  36023.875000
# 2013  202112상순  감자  감자 수미  20키로상자  상  31688.643519  35233.666667
# 2014  202112중순  감자  감자 수미  20키로상자  상  33251.916667  32679.125000
# 2015  202112하순  감자  감자 수미  20키로상자  상  34313.181481  42440.600000
#
# [144 rows x 7 columns]

# %%
train_meta_1.head(1)
# Out:
#          시점       공판장코드      공판장명  품목코드 품목명   품종코드 품종명  등급코드 등급명  총반입량(kg)  \
# 0  201801상순  1000000000  *전국농협공판장   501  감자  50101  수미    11   특   15470.0
#
#    ...    평균가(원/kg)    중간가(원/kg)    최저가(원/kg)    최고가(원/kg)  경매 건수  \
# 0  ...  1712.637363  1723.961039  1545.454545  2320.666667      7
#
#    전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 0               1947.350427                  1769.85832
#
#    전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON    연도
# 0               1023.982379                          0.0  2018
#
# [1 rows x 21 columns]

# %%
train_meta_1['품목명'].unique() # 건고추가 없다
# Out:
# array(['감자', '사과', '배', '배추', '상추', '무', '양파', '대파', '마늘', '순무'],
#       dtype=object)

# %%
potato = train_meta_1[(train_meta_1['품목명']=='감자') & (train_meta_1['품종명']=='수미')]
potato.groupby('공판장명').count()
# Out:
#                    시점  공판장코드  품목코드  품목명  품종코드  품종명  등급코드  등급명  총반입량(kg)  \
# 공판장명
# *전국농협공판장          805    805   805  805   805  805   805  805       805
# 거창사과원예농협            1      1     1    1     1    1     1    1         1
# 경주농협 공판장          185    185   185  185   185  185   185  185       185
# 군산원예농업협동조합        398    398   398  398   398  398   398  398       398
# 김제원예농업협동조합공판장      22     22    22   22    22   22    22   22        22
# 김천농협공판장            88     88    88   88    88   88    88   88        88
# 나주배농업협동조합           3      3     3    3     3    3     3    3         3
# 남원원협공판장           200    200   200  200   200  200   200  200       200
# 논산계룡농협농산물공판장        2      2     2    2     2    2     2    2         2
# 대관령원예농협공판사업소      210    210   210  210   210  210   210  210       210
# 대구공판장             237    237   237  237   237  237   237  237       237
# 동남해농협 삼동지점(공판)      1      1     1    1     1    1     1    1         1
# ...

# %%
potato = train_meta_1[(train_meta_1['품목명']=='감자') & (train_meta_1['품종명']== '수미') & (train_meta_1['등급명']== '상')]
potato.describe()
# Out:
#               공판장코드   품목코드     품종코드   등급코드      총반입량(kg)      총거래금액(원)  \
# count  7.730000e+02  773.0    773.0  773.0    773.000000  7.730000e+02
# mean   3.102088e+09  501.0  50101.0   12.0   1749.715395  1.497758e+06
# std    1.462583e+09    0.0      0.0    0.0   3381.991023  3.123969e+06
# min    1.000000e+09  501.0  50101.0   12.0      1.000000  1.000000e+03
# 25%    1.278201e+09  501.0  50101.0   12.0    120.000000  7.700000e+04
# 50%    3.048206e+09  501.0  50101.0   12.0    610.000000  3.940000e+05
# 75%    4.128509e+09  501.0  50101.0   12.0   1860.000000  1.298000e+06
# max    6.198200e+09  501.0  50101.0   12.0  31035.000000  2.715660e+07
#
#           평균가(원/kg)     중간가(원/kg)     최저가(원/kg)     최고가(원/kg)       경매 건수  \
# count    773.000000    773.000000    773.000000    773.000000  773.000000
# mean     807.472168    780.053739    586.226113   1031.232588    7.182406
# std      692.497518    684.097175    658.506332    815.891370    9.602817
# ...

# %%
potato
# Out:
#               시점       공판장코드        공판장명  품목코드 품목명   품종코드 품종명  등급코드 등급명  \
# 1       201801상순  1000000000    *전국농협공판장   501  감자  50101  수미    12   상
# 156     201801상순  3048206353     제천농협공판장   501  감자  50101  수미    12   상
# 381     201801상순  4128509458       대구공판장   501  감자  50101  수미    12   상
# 617     201801중순  1000000000    *전국농협공판장   501  감자  50101  수미    12   상
# 753     201801중순  3048206353     제천농협공판장   501  감자  50101  수미    12   상
# ...          ...         ...         ...   ...  ..    ...  ..   ...  ..
# 117423  202112중순  3108203711  충서원협농산물공판장   501  감자  50101  수미    12   상
# 117931  202112하순  1000000000    *전국농협공판장   501  감자  50101  수미    12   상
# 118090  202112하순  3048206353     제천농협공판장   501  감자  50101  수미    12   상
# 118150  202112하순  3108203711  충서원협농산물공판장   501  감자  50101  수미    12   상
# 118188  202112하순  4018200719  군산원예농업협동조합   501  감자  50101  수미    12   상
#
#         총반입량(kg)  ...    평균가(원/kg)    중간가(원/kg)    최저가(원/kg)    최고가(원/kg)  \
# ...

# %%
# potato.drop(['공판장코드', '공판장명', '품목코드', '품종코드', '품종명', '등급코드', '등급명',], axis=1, inplace=True)
# Out:
# /var/folders/xg/fp1_kg411bl0yfm4mg9jjycm0000gn/T/ipykernel_31900/4106679806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   potato.drop(['공판장코드', '공판장명', '품목코드', '품종코드', '품종명', '등급코드', '등급명',], axis=1, inplace=True)

# %%
potato_df = potato.groupby(['시점', '품목명']).mean(numeric_only=True).reset_index()
potato_df
# Out:
#            시점 품목명         공판장코드   품목코드     품종코드  등급코드     총반입량(kg)  \
# 0    201801상순  감자  2.725572e+09  501.0  50101.0  12.0  1933.333333
# 1    201801중순  감자  3.281153e+09  501.0  50101.0  12.0   855.000000
# 2    201801하순  감자  2.688802e+09  501.0  50101.0  12.0   646.666667
# 3    201802상순  감자  2.725572e+09  501.0  50101.0  12.0  6000.000000
# 4    201802중순  감자  2.024103e+09  501.0  50101.0  12.0  1040.000000
# ..        ...  ..           ...    ...      ...   ...          ...
# 137  202111중순  감자  2.892562e+09  501.0  50101.0  12.0   276.000000
# 138  202111하순  감자  2.336152e+09  501.0  50101.0  12.0   220.000000
# 139  202112상순  감자  2.024103e+09  501.0  50101.0  12.0  2520.000000
# 140  202112중순  감자  2.385470e+09  501.0  50101.0  12.0  1146.666667
# 141  202112하순  감자  2.793653e+09  501.0  50101.0  12.0   745.000000
#
#          총거래금액(원)    평균가(원/kg)    중간가(원/kg)    최저가(원/kg)    최고가(원/kg)  \
# 0    2.317400e+06  1249.397085  1263.266900  1091.281676  1445.238095
# ...

# %%
train_df[(train_df['품목명']=='감자') & (train_df['품종명']== '감자 수미') & (train_df['등급']== '상')]
# Out:
#             시점 품목명    품종명    거래단위 등급    평년 평균가격(원)       평균가격(원)
# 1872  201801상순  감자  감자 수미  20키로상자  상  24660.031746  44170.285714
# 1873  201801중순  감자  감자 수미  20키로상자  상  23299.444444  48283.777778
# 1874  201801하순  감자  감자 수미  20키로상자  상  25218.007407  50243.000000
# 1875  201802상순  감자  감자 수미  20키로상자  상  28703.875000  55380.666667
# 1876  201802중순  감자  감자 수미  20키로상자  상  27419.882275  59133.000000
# ...        ...  ..    ...     ... ..           ...           ...
# 2011  202111중순  감자  감자 수미  20키로상자  상  30634.777778  33761.333333
# 2012  202111하순  감자  감자 수미  20키로상자  상  32139.787037  36023.875000
# 2013  202112상순  감자  감자 수미  20키로상자  상  31688.643519  35233.666667
# 2014  202112중순  감자  감자 수미  20키로상자  상  33251.916667  32679.125000
# 2015  202112하순  감자  감자 수미  20키로상자  상  34313.181481  42440.600000
#
# [144 rows x 7 columns]

# %%
train_meta_2.head(1)
# Out:
#          시점    시장코드      시장명  품목코드 품목명   품종코드  품종명  총반입량(kg)  총거래금액(원)  \
# 0  201801상순  100000  *전국도매시장   501  감자  50124  깐감자      20.0     86520
#
#    평균가(원/kg)  고가(20%) 평균가  중가(60%) 평균가   저가(20%) 평균가  중간가(원/kg)  최저가(원/kg)  \
# 0     4326.0          0.0           0.0       4326.0     4326.0     4326.0
#
#    최고가(원/kg)  경매 건수  전순 평균가격(원) PreVious SOON  전달 평균가격(원) PreVious MMonth  \
# 0     4326.0      1                       0.0                      4009.0
#
#    전년 평균가격(원) PreVious YeaR  평년 평균가격(원) Common Year SOON    연도
# 0                       0.0                          0.0  2018

# %%
potato1 = train_meta_2[(train_meta_2['품목명']=='감자') & (train_meta_2['품종명']== '수미')]
potato1
# Out:
#               시점    시장코드      시장명  품목코드 품목명   품종코드 품종명   총반입량(kg)    총거래금액(원)  \
# 8       201801상순  100000  *전국도매시장   501  감자  50101  수미  2423696.5  4135898623
# 113     201801상순  110001     서울가락   501  감자  50101  수미  1272705.5  2110894450
# 161     201801상순  110008     서울강서   501  감자  50101  수미    70320.0   112287500
# 191     201801상순  210001     부산엄궁   501  감자  50101  수미   105020.0   178672800
# 233     201801상순  210009     부산반여   501  감자  50101  수미    17568.0    30235500
# ...          ...     ...      ...   ...  ..    ...  ..        ...         ...
# 175762  202112하순  350301       익산   501  감자  50101  수미      200.0      380000
# 175806  202112하순  360301       순천   501  감자  50101  수미     8180.0     9698500
# 175865  202112하순  371501       구미   501  감자  50101  수미    61700.0    99602900
# 175918  202112하순  380201       울산   501  감자  50101  수미    11940.0    14015000
# 175986  202112하순  380401       진주   501  감자  50101  수미    10000.0    21006100
#
# ...

# %%
potato_df1 = potato1.groupby(['시점', '품목명']).mean(numeric_only=True).reset_index()
potato_df1
# Out:
#            시점 품목명           시장코드   품목코드     품종코드       총반입량(kg)      총거래금액(원)  \
# 0    201801상순  감자  282369.571429  501.0  50101.0  173121.178571  2.954213e+08
# 1    201801중순  감자  283451.714286  501.0  50101.0  146554.471429  2.617663e+08
# 2    201801하순  감자  284558.400000  501.0  50101.0  132082.473333  2.498778e+08
# 3    201802상순  감자  282369.571429  501.0  50101.0  200765.228571  4.317602e+08
# 4    201802중순  감자  279861.000000  501.0  50101.0   94628.037037  2.040133e+08
# ..        ...  ..            ...    ...      ...            ...           ...
# 139  202111중순  감자  279097.961538  501.0  50101.0   92828.307692  1.122517e+08
# 140  202111하순  감자  278705.576923  501.0  50101.0   92343.307692  1.231644e+08
# 141  202112상순  감자  278705.576923  501.0  50101.0  136502.615385  1.889315e+08
# 142  202112중순  감자  278705.576923  501.0  50101.0   97703.461538  1.287592e+08
# 143  202112하순  감자  275049.760000  501.0  50101.0  133980.640000  2.106486e+08
#
# ...

# %%
potato_df1.describe()
# Out:
#                 시장코드   품목코드     품종코드       총반입량(kg)      총거래금액(원)  \
# count     144.000000  144.0    144.0     144.000000  1.440000e+02
# mean   286363.404972  501.0  50101.0  212720.418284  2.588377e+08
# std      4531.042880    0.0      0.0  102587.425993  1.359964e+08
# min    274006.041667  501.0  50101.0   61409.692308  9.312017e+07
# 25%    282877.841931  501.0  50101.0  151752.918135  1.498646e+08
# 50%    287201.800000  501.0  50101.0  186721.514423  2.218396e+08
# 75%    289917.375000  501.0  50101.0  234512.784752  3.349454e+08
# max    293679.812500  501.0  50101.0  653790.956250  7.091919e+08
#
#          평균가(원/kg)  고가(20%) 평균가  중가(60%) 평균가   저가(20%) 평균가    중간가(원/kg)  \
# count   144.000000   144.000000    144.000000   144.000000   144.000000
# mean   1269.138955  1649.619624   1299.806698   730.701957  1033.118459
# std     586.406193   701.167159    616.901217   382.094055   474.194848
# min     580.157376   802.130562    610.601846   271.440911   481.696120
# ...
